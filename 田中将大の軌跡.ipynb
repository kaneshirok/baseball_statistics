# %%
# 必要なライブラリのインポート
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt
# 表示列・行を増やす(30列, 10行)
pd.options.display.max_columns = 30
pd.options.display.max_rows = 10

# %%
url = 'http://npb.jp/bis/players/11215114.html'
# htmlのテーブルをDataFrameで取得
tanaka_df = pd.read_html(url, header=0)

# %%
tanaka_df[1]
# Out:
#         年度  所属球団     登板    勝利    敗北  セーブ    H   HP    完投   完封勝   無四球     勝率  \
# 0   2007.0  東北楽天   28.0  11.0   7.0  0.0  0.0  0.0   4.0   1.0   0.0  0.611
# 1    186.0    .1    NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN
# 2   2008.0  東北楽天   25.0   9.0   7.0  1.0  0.0  0.0   5.0   2.0   1.0  0.563
# 3    172.0    .2    NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN
# 4   2009.0  東北楽天   25.0  15.0   6.0  1.0  0.0  0.0   6.0   3.0   0.0  0.714
# ..     ...   ...    ...   ...   ...  ...  ...  ...   ...   ...   ...    ...
# 10  2012.0  東北楽天   22.0  10.0   4.0  0.0  0.0  0.0   8.0   3.0   4.0  0.714
# 11   173.0   NaN    NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN
# 12  2013.0  東北楽天   28.0  24.0   0.0  1.0  0.0  0.0   8.0   2.0   1.0  1.000
# 13   212.0   NaN    NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN
# 14     NaN   通　算  175.0  99.0  35.0  3.0  0.0  0.0  53.0  18.0  12.0  0.739
#
# ...

# %%
# 上手く取れていないので修正する
